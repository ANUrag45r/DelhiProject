# %% [markdown]
# <a href="https://colab.research.google.com/github/ANUrag45r/DelhiProject/blob/main/machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Machine learning :**- it is wasy to teavh computers/machine to learn from data. instead of prgramming on their own we give machines a lot of data and let them figure out patterns on their own
#
# difference between AI/ML/DL
#
# AI--> thik of this as a big umbrella. it is the science of making machine smarter
#
#
# ML--> it is the subset of AI. this is where machine learns form data and improve over the time.
#
#
# DL--> it is the subset of ML. it uses something called Neural Networks which is inspired by human Brain
#
# Types of ML:-
#
# 1.   supervised learning
# 2.   unsupervised learning
# 3.   reinforcement learning
#
#
#
# ---
#
# 1. **Supervised learning:-** --> we give machine input data and the correct answer -- and it learns to predict
#
# the training of the model is done via multiple meathods these meathods are called algorithms
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. unsuperwised learning:- here we will also get the data but we are not going to perdict anything we willjust find patterns , group similar items, Reduce complexity and spot oultiers
#
# 3. reinforcement learning:- you dont teach everything directly instead tou reward good behaviours and punish bad actions . basically learning by trial and error

# %% [markdown]
# ***EDA - exploratory data analysis***
# lets see steps involved in making a machine learning model

# %% [markdown]
# steps of making a machine learning model

# %% [markdown]
# 1. problem defination
# 2. data collection
# 3. EDA
# 4. data preprocessing/cleaning
# 5. feature selection and engineering
# 6. split the dataset
# 7. model section
# 8. model training
# 9. model evaluation
# 10. hyperparameter tuning
# 11. model testing

# %% [markdown]
# first 2 steps are very intutive in nature so one can just use standard resources like kaggle and all stuffs to collect and analyze it

# %% [markdown]
# step 3 :-

# %% [markdown]
# EDA

# %% [markdown]
# this is a step where u explore data to
# 1. undestand it
# 2. Discover patterns
# 3. spot anomalies
# 4. Generate insights
# 5. And at the end decide what to do next

# %% [markdown]
# lets now go deeper in each steps

# %% [markdown]
# 1. understand it
# basically viewing the data
#
#
# *   head(), tail(), shape, info()
# *   what columns do i have, what types of data
#
# 2. summary statistics
#
#
# *   mean, median , model, min, max , quartiles
# *   helps understand spread and central tendency
#
# 3. missing value analysis
#
#
# *   where are the gaps
# *   what data is actually missing
#
# 4. visualization
#
#
# *   histograms
# *   Boxplots
#
#
# *   corelation heatmaps
# *   scatter plots
#
# 5. target variable exploration
#
#
# *   how your output is related to other variables

# %% [markdown]
# EDA importance:-
# 1. you cannot clean or preprocess data which u didn't understand
# 2. helps u undestand mistakes, biases, limitations of your data
#
# now as you have analyzed your data  in detail next we got to step 4

# %% [markdown]
# step - 4:-
#  DATA CLEANING

# %% [markdown]
# 1. handeling missing values:-
